# %% [markdown]
# # Advance Opration with Business Examples

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Data Structure: [restaurent_id, 2021, 2022, 2023, 2024]

sales_data = np.array([
    [1, 120000, 230000, 150000, 230000], # Paradise Biryani
    [2, 120000, 130000, 140000, 135000], # Beijing Bites
    [3, 200000, 230000, 125000, 310000], # Pizza Hub
    [4, 123456, 213400, 310000, 190000], # Burger Point
    [5, 160000, 180000, 170000, 175000]  # Chai Point
])

print("=== Zomato Sales Analysis ===\n")
print(f"Sales data shape: {sales_data.shape}")
print(f"Sample data for 1st 3 restau:\n{sales_data[:3, 1:]}")
# Out:
# === Zomato Sales Analysis ===
#
# Sales data shape: (5, 5)
# Sample data for 1st 3 restau:
# [[120000 230000 150000 230000]
#  [120000 130000 140000 135000]
#  [200000 230000 125000 310000]]

# %%
# Total sales per year
print("Sales per year:", np.sum(sales_data[:, 1:], axis=0))
yearly_total = np.sum(sales_data[:, 1:], axis=1)
print("Yearly total per restro:", yearly_total)

# Minimum sales per restaurant
min_sales = np.min(sales_data[:, 1:], axis=1) # axis: 1 for rows, 0 for columns
print(f"Min sales per restaurant: {min_sales}")

# Maximum sales per year
max_sales = np.max(sales_data[:, 1:], axis=0)
print(f"Max sales per year: {max_sales}")

# Average sales per restaurant
avg_salaes = np.mean(sales_data[:, 1:], axis=1)
print(f"Average sales per restaurant: {avg_salaes}")
# Out:
# Sales per year: [ 723456  983400  895000 1040000]
# Yearly total per restro: [730000 525000 865000 836856 685000]
# Min sales per restaurant: [120000 120000 125000 123456 160000]
# Max sales per year: [200000 230000 310000 310000]
# Average sales per restaurant: [182500. 131250. 216250. 209214. 171250.]

# %%
cumsum = np.cumsum(sales_data[:, 1:], axis=1)
print(f"Cumulative Sales:\n{cumsum}")

plt.figure(figsize=(8, 6))
plt.plot(np.mean(cumsum, axis=0))
plt.title("Average Cumulative Sales Accross All Reataurants")
plt.xlabel("Years")
plt.ylabel("Sales")
plt.grid(True)
plt.show()
# Out:
# Cumulative Sales:
# [[120000 350000 500000 730000]
#  [120000 250000 390000 525000]
#  [200000 430000 555000 865000]
#  [123456 336856 646856 836856]
#  [160000 340000 510000 685000]]

# %%
vector_1 = np.array([1, 2, 3, 4, 5])
vector_2 = np.array([6, 7, 8, 9, 10])

print(f"Vector Addition: {vector_1 + vector_2}")
print(f"vector Multiplication: {vector_1 * vector_2}")
print(f"Vactor Dot Product: {np.dot(vector_1, vector_2)}")

angle = np.arccos(np.dot(vector_1, vector_2) / (np.linalg.norm(vector_1) * np.linalg.norm(vector_2)))
print(f"Angle: {angle}")
# Out:
# Vector Addition: [ 7  9 11 13 15]
# vector Multiplication: [ 6 14 24 36 50]
# Vactor Dot Product: 130
# Angle: 0.26554161733900966

# %%
# Vactorized Operation

restaurant_types = np.array(['biryani', 'chinese', 'pizza', 'burger', 'cafe'])
vectorized_upper = np.vectorize(str.upper)
print("Vectorized Upper:", vectorized_upper(restaurant_types))
# Out:
# Vectorized Upper: ['BIRYANI' 'CHINESE' 'PIZZA' 'BURGER' 'CAFE']

# %%
# Broadcast

monthly_avg = sales_data[:, 1:]
print(f"Monthly Average:\n{monthly_avg}")

monthly_avg = sales_data[:, 1:] / 12
print(f"\n\nMonthly Average Updated:\n{monthly_avg}")
# Out:
# Monthly Average:
# [[120000 230000 150000 230000]
#  [120000 130000 140000 135000]
#  [200000 230000 125000 310000]
#  [123456 213400 310000 190000]
#  [160000 180000 170000 175000]]
#
#
# Monthly Average Updated:
# [[10000.         19166.66666667 12500.         19166.66666667]
#  [10000.         10833.33333333 11666.66666667 11250.        ]
#  [16666.66666667 19166.66666667 10416.66666667 25833.33333333]
#  [10288.         17783.33333333 25833.33333333 15833.33333333]
#  [13333.33333333 15000.         14166.66666667 14583.33333333]]
