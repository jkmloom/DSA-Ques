# %% [markdown]
# # Advance Side of Numpy

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
array1 = np.array([[1, 2, 3], [4, 5, 6]])
array2 = np.random.rand(3, 3)
array3 = np.zeros((4, 4))

# %%
# Save Arrays in Flat Files
np.save('array1.npy', array1)
np.save('array2.npy', array2)
np.save('array3.npy', array3)

# %%
loaded_array_1 = np.load('array1.npy')
print(loaded_array_1)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
try:
    img = np.load('images.npy')
    # Display
    plt.figure(figsize=(10, 5))
    plt.subplot(121)
    # plt.imshow(img)
    plt.title("Image in .npy format")
    plt.grid(False)

    dark_mode = 1 - img
    plt.subplot(122)
    # plt.imshow(dark_mode)
    plt.title("Image updated to dark mode")

except FileNotFoundError:
    print("Logo file not found!")
